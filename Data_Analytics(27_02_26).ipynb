# %% [markdown]
# <a href="https://colab.research.google.com/github/Pankhuri321/CODSOFT/blob/main/Data_Analytics(27_02_26).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import StandardScaler

# Standardize data
data = [[10, 2], [15, 5], [20, 3]]
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
print(scaled_data)
# Out:
# [[-1.22474487 -1.06904497]
#  [ 0.          1.33630621]
#  [ 1.22474487 -0.26726124]]

# %%
import numpy as np

# Create an array and perform element-wise operations
array = np.array([1, 2, 3, 4])
squared_array = np.square(array)

print(squared_array)
# Out:
# [ 1  4  9 16]

# %%
import pandas as pd

# Load a sample dataset
data = pd.DataFrame({
    'name': ['John', 'Jane', 'Jack'],
    'age': [28, 31, 34]
})

print(data)
# Out:
#    name  age
# 0  John   28
# 1  Jane   31
# 2  Jack   34
